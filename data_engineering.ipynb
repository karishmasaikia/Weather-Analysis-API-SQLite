# %%
import pandas as pd

# %%
file_path_measurements='hawaii_measurements.csv'
file_path_stations='hawaii_stations.csv'

# %%
csv_measurements=pd.read_csv(file_path_measurements)
csv_measurements.head(3)
# Out:
#        station        date  prcp  tobs
# 0  USC00519397  2010-01-01  0.08    65
# 1  USC00519397  2010-01-02  0.00    63
# 2  USC00519397  2010-01-03  0.00    74

# %%
csv_stations=pd.read_csv(file_path_stations)
csv_stations.head(3)
# Out:
#        station                                    name  latitude  longitude  \
# 0  USC00519397                    WAIKIKI 717.2, HI US   21.2716  -157.8168
# 1  USC00513117                    KANEOHE 838.1, HI US   21.4234  -157.8015
# 2  USC00514830  KUALOA RANCH HEADQUARTERS 886.9, HI US   21.5213  -157.8374
#
#    elevation
# 0        3.0
# 1       14.6
# 2        7.0

# %%
csv_measurements.dtypes
# Out:
# station     object
# date        object
# prcp       float64
# tobs         int64
# dtype: object

# %%
csv_stations.dtypes
# Out:
# station       object
# name          object
# latitude     float64
# longitude    float64
# elevation    float64
# dtype: object

# %%
csv_stations.count()
# Out:
# station      9
# name         9
# latitude     9
# longitude    9
# elevation    9
# dtype: int64

# %%
csv_measurements.count()
# Out:
# station    19550
# date       19550
# prcp       18103
# tobs       19550
# dtype: int64

# %%
clean_csv_measurements=csv_measurements.dropna(how='any')
clean_csv_measurements.count()
# Out:
# station    18103
# date       18103
# prcp       18103
# tobs       18103
# dtype: int64

# %%
clean_csv_measurements.to_csv('clean_hawaii_measurements.csv',index=False)
csv_stations.to_csv('clean_hawaii_stations.csv',index=False)
